# %% [markdown]
# **Práctica Break, Continue, Pass**
#
# **Objetivo**
#
# En este caso práctico se propone al alumno "Programar el software de un despertador". Para ello debe hacer uso de las sentencias de control de flujo vistas en clases anteriores en combinación con las sentencias break, continue y pass.
#
#
#
# Instrucciones
#
# Define una función llamada simulador_alarma que acepte un parámetro: tiempo_total. Este parámetro indica la cantidad total de "segundos" (iteraciones) que el simulador debe ejecutarse.
#
# Dentro de la función, inicializa una variable segundo_actual en 0. Esta variable funcionará como contador para simular el paso del tiempo.
#
# Implementa un bucle while que continúe ejecutándose hasta que segundo_actual alcance el valor de tiempo_total.
#
# En cada iteración del bucle, incrementa segundo_actual en 1 para simular el paso de un segundo.
#
# Utiliza la sentencia continue para "pausar" la alarma cada 10 "segundos".
#
# Asegúrate de imprimir un mensaje cada vez que se "pausa" la alarma, indicando que se ha omitido un segundo específico.
#
# Imprime un mensaje en cada iteración que no se pausa para indicar que la alarma está activada y para mostrar el segundo actual.
#
# Emplea la sentencia break para terminar el bucle y finalizar la simulación de la alarma cuando segundo_actual alcance el valor de tiempo_total.
#
# Imprime un mensaje final para indicar que la alarma se ha desactivado, especificando el total de "segundos" que estuvo activa.
#
# Invoca la función simulador_alarma.
#
#
#
# Resultado esperado
#
# Alarma activada, segundo actual: 1
#
# Alarma activada, segundo actual: 2
#
# Alarma activada, segundo actual: 3
#
# Alarma activada, segundo actual: 4
#
# Alarma activada, segundo actual: 5
#
# Alarma activada, segundo actual: 6
#
# Alarma activada, segundo actual: 7
#
# Alarma activada, segundo actual: 8
#
# Alarma activada, segundo actual: 9
#
# Omitiendo alarma en segundo 10
#
# Alarma activada, segundo actual: 11
#
# Alarma activada, segundo actual: 12
#
# Alarma activada, segundo actual: 13
#
# Alarma activada, segundo actual: 14
#
# Alarma activada, segundo actual: 15
#
# Alarma activada, segundo actual: 16
#
# Alarma activada, segundo actual: 17
#
# Alarma activada, segundo actual: 18
#
# Alarma activada, segundo actual: 19
#
# Omitiendo alarma en segundo 20
#
# Alarma activada, segundo actual: 21
#
# Alarma desactivada a los 21 segundos

# %%
def simulador_alarma(tiempo_total):
    segundo_actual = 0
    while segundo_actual != tiempo_total:
        segundo_actual += 1
        
        if (segundo_actual % 10) == 0:
            print(f"Omitiendo alarma en segundo {segundo_actual}")
            continue
        
        print(f"Alarma activada, segundo actual: {segundo_actual}")
        
        if segundo_actual == tiempo_total:
            print(f"Alarma desactivada a los {segundo_actual} segundos")
            break

simulador_alarma(35)
# Out:
# Alarma activada, segundo actual: 1
# Alarma activada, segundo actual: 2
# Alarma activada, segundo actual: 3
# Alarma activada, segundo actual: 4
# Alarma activada, segundo actual: 5
# Alarma activada, segundo actual: 6
# Alarma activada, segundo actual: 7
# Alarma activada, segundo actual: 8
# Alarma activada, segundo actual: 9
# Omitiendo alarma en segundo 10
# Alarma activada, segundo actual: 11
# Alarma activada, segundo actual: 12
# Alarma activada, segundo actual: 13
# Alarma activada, segundo actual: 14
# Alarma activada, segundo actual: 15
# Alarma activada, segundo actual: 16
# Alarma activada, segundo actual: 17
# Alarma activada, segundo actual: 18
# Alarma activada, segundo actual: 19
# Omitiendo alarma en segundo 20
# Alarma activada, segundo actual: 21
# Alarma activada, segundo actual: 22
# Alarma activada, segundo actual: 23
# Alarma activada, segundo actual: 24
# Alarma activada, segundo actual: 25
# Alarma activada, segundo actual: 26
# ...
