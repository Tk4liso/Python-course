# %% [markdown]
# # Sentencias `break`, `continue` y `pass`

# %% [markdown]
# ### 1. ¿Qué es la sentencia `break`?

# %% [markdown]
# La sentencia `break` es una palabra reservada del lenguaje Python que podemos utilizar para terminar de manera inmediata la ejecución de una estructura de control de flujo `for` o `while`. El flujo de ejecución del programa pasará a la siguiente línea de código que se encuentre fuera de la estructura de control flujo.

# %%
colores = ["rojo", "verde", "azul"]

# %%
for color in colores:
    print(color)
# Out:
# rojo
# verde
# azul

# %%
for color in colores:
    print(color)
    break

print("Esto es una sentencia fuera del bucle for")
# Out:
# rojo
# Esto es una sentencia fuera del bucle for

# %%
for color in colores:
    break
    print(color)

print("Esto es una sentencia fuera del bucle for")
# Out:
# Esto es una sentencia fuera del bucle for

# %%
num = 5

# %%
while num > 0:
    print(num)
    num -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
num = 5

# %%
while num > 0:
    print(num)
    num -= 1
    break
# Out:
# 5

# %%
print(num)
# Out:
# 4

# %% [markdown]
# Una de las cosas importantes que debemos tener en cuenta cuando estamos utilizando la sentencia `break` es que no se ejecutarán las líneas de código que pongamos en la claúsula `else`.

# %%
colores
# Out:
# ['rojo', 'verde', 'azul']

# %%
for color in colores:
    print(color)
    break
else:
    print("Ejecución en la cláusula else")
# Out:
# rojo

# %% [markdown]
# ### 2. ¿Qué es la sentencia `continue`?

# %% [markdown]
# La sentencia `continue` es otra palabra reservada de Python sin embargo, a diferencia de la sentencia `break`, **no termina la ejecución completa de los bucles `for` y `while` sino que termina únicamente la ejecución de la iteración actual EN EL PUNTO EN EL QUE SE ENCUENTRA LA PALABRA** *"continue"*. O sea, se salta la iteración actual y pasa a la siguiente.

# %%
colores = ["azul", "verde", "rojo"]

# %%
for color in colores:
    print(color)
# Out:
# azul
# verde
# rojo

# %%
for color in colores:
    print(color)
    break
# Out:
# azul

# %%
for color in colores:
    print(color)
    continue
# Out:
# azul
# verde
# rojo

# %%
for color in colores:
    continue
    print(color)

# %%
for color in colores:
    print(color)
    continue
    print("Sentencia después de continue")
# Out:
# azul
# verde
# rojo

# %%
for color in colores:
    if color == "verde":
        continue
    print(color)
# Out:
# azul
# rojo

# %%
num = 5
while num > 0:
    num -= 1
    if num == 2:
        continue
    print(num)
# Out:
# 4
# 3
# 1
# 0

# %% [markdown]
# ### 3. ¿Qué es la sentencia `pass`?

# %% [markdown]
# La sentencia `pass` es una palabra reservada de Python que nos permite definir el esqueleto de diferentes estructuras de diferentes tipos (funciones, if, while, for...) sin indicarle ninguna línea de código en el cuerpo de la estructura.

# %%
def funcion():
# Out:
#   Cell In[31], line 2
#
#     ^
# SyntaxError: incomplete input

# %%
def funcion():
    pass

# %%
colores = ["rojo", "verde", "azul"]

# %%
for color in colores:
    #Aquí voy a hacer algo que todavía no se
# Out:
#   Cell In[34], line 2
#     #Aquí voy a hacer algo que todavía no se
#                                             ^
# SyntaxError: incomplete input

# %%
for color in colores:
    #Aquí voy a hacer algo que todavía no se
    pass
